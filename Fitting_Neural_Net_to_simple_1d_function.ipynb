# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import layers as kl
from tensorflow.keras import backend as K
from tensorflow_probability import distributions as tfd

import  matplotlib.pyplot as plt

# %%
def fun(x):
    return x**2

# %%
X = tfd.Uniform(-1, 1).sample([10000, 1])
Y = fun(X)

# %%
model = Sequential([
    kl.Input(1), 
    kl.Dense(4, "relu"), 
#    kl.Dense(8, "relu"), 
    kl.Dense(4, "relu"), 
    kl.Dense(1, "relu")
])

# %%
model = Sequential([
    kl.Input(1), 
    kl.Dense(4, "softplus"), 
#    kl.Dense(8, "relu"), 
    kl.Dense(4, "softplus"), 
    kl.Dense(1, "softplus")
])

# %%
model.weights
# Out:
# [<tf.Variable 'dense_28/kernel:0' shape=(1, 4) dtype=float32, numpy=array([[ 0.6943109, -0.8936696, -0.289496 , -0.664577 ]], dtype=float32)>,
#  <tf.Variable 'dense_28/bias:0' shape=(4,) dtype=float32, numpy=array([0., 0., 0., 0.], dtype=float32)>,
#  <tf.Variable 'dense_29/kernel:0' shape=(4, 4) dtype=float32, numpy=
#  array([[ 0.58344144, -0.20922369,  0.51060325, -0.1664207 ],
#         [-0.24453247,  0.44665092,  0.79311126,  0.0865981 ],
#         [-0.6656709 ,  0.07742643,  0.2916997 , -0.2644593 ],
#         [ 0.26620692,  0.1806261 , -0.5962262 , -0.11011642]],
#        dtype=float32)>,
#  <tf.Variable 'dense_29/bias:0' shape=(4,) dtype=float32, numpy=array([0., 0., 0., 0.], dtype=float32)>,
#  <tf.Variable 'dense_30/kernel:0' shape=(4, 1) dtype=float32, numpy=
#  array([[-0.27405167],
#         [ 0.4395789 ],
#         [-0.57316434],
#         [ 0.02162814]], dtype=float32)>,
#  <tf.Variable 'dense_30/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %%
model(tf.constant([[1]]))
# Out:
# <tf.Tensor: id=272652, shape=(1, 1), dtype=float32, numpy=array([[0.45211807]], dtype=float32)>

# %%
model.compile(optimizer="adam", loss="mse")

# %%
model.fit(X, Y, validation_split=(0.3), epochs=200)
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/200
# 7000/7000 [==============================] - 0s 39us/sample - loss: 5.5891e-04 - val_loss: 5.7589e-04
# Epoch 2/200
# 7000/7000 [==============================] - 0s 38us/sample - loss: 5.4714e-04 - val_loss: 5.6463e-04
# Epoch 3/200
# 7000/7000 [==============================] - 0s 38us/sample - loss: 5.4680e-04 - val_loss: 5.7202e-04
# Epoch 4/200
# 7000/7000 [==============================] - 0s 38us/sample - loss: 5.4262e-04 - val_loss: 5.6654e-04
# Epoch 5/200
# 7000/7000 [==============================] - 0s 38us/sample - loss: 5.3158e-04 - val_loss: 5.5198e-04
# Epoch 6/200
# 7000/7000 [==============================] - 0s 38us/sample - loss: 5.3201e-04 - val_loss: 5.4845e-04
# Epoch 7/200
# 7000/7000 [==============================] - 0s 38us/sample - loss: 5.3051e-04 - val_loss: 5.4005e-04
# Epoch 8/200
# 7000/7000 [==============================] - 0s 39us/sample - loss: 5.2633e-04 - val_loss: 5.6942e-04
# ...

# %%
xxx = np.linspace(-1, 1, 100, dtype=K.floatx())[:, None]
plt.plot(xxx, np.squeeze(fun(xxx)))
plt.plot(xxx, np.squeeze(model(xxx)))

# %%
xxx = np.linspace(-1, 1, 100, dtype=K.floatx())[:, None]
plt.plot(xxx, np.squeeze(fun(xxx)))
plt.plot(xxx, np.squeeze(model(xxx)))
