# %%
import base64

import matplotlib.pyplot as pl
import numpy as np

from IPython.core.display import HTML

# %%
fig, ax = pl.subplots()
xxx = np.linspace(-1, 1, 100)
ax.plot(xxx, xxx**2)

# %%
import io

# %%
file = io.BytesIO()

# %%
fig.savefig(file, format = "png")

# %%
file.seek(0)
file.read()[:10]
# Out:
# b'\x89PNG\r\n\x1a\n\x00\x00'

# %%
file.seek(0)
img_str = base64.b64encode(file.read()).decode().replace("\n", "")

# %%
template = """
<!DOCTYPE html>
<html>
<body>
<p>This is a paragraph.</p>
<img src="data:image/png;base64,{}" alt="whatever">

</body>
</html>
"""

# %%
HTML(template.format(img_str))
# Out:
# <!DOCTYPE html>
# <html>
# <body>
# <p>This is a paragraph.</p>
# <img src="data:image/png;base64,..." alt="whatever">
#
# </body>
# </html>
